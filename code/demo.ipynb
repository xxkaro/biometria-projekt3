# %%
from fingerprint_processor import FingerprintProcessor

# %%
FP = FingerprintProcessor()

# %%
FP = FingerprintProcessor()
FP.load_image("../sample_data/Black-Fingerprint-Loop-on-White-Space.jpg.webp")

FP.display_image()     

FP.normalize_fingerprint(100, 100)    

FP.fingerprint_segmentation() 

FP.create_directional_map()             

FP.frequency_map()              

FP.apply_gabor_filter()


FP.morphological_skeletonization()

FP.detect_minutiae()
# Out:
# Loaded image ../sample_data/Black-Fingerprint-Loop-on-White-Space.jpg.webp with shape (483, 724)
# Fingerprint normalized
# Fingerprint segmented
# Directional map created
# Frequency map created
# Median frequency: 0.1666666716337204
# Gabor filter applied
# Image saved to filtered_image.bmp
# Image saved to morph_skeleton.bmp
# Morphological skeletonization completed
# Detected 1251 endings and 2686 bifurcations

# %%
FP.skeletonize_with_kmm()

FP.detect_minutiae()
# Out:
# Image saved to kmm_skeleton.bmp
# KMM skeletonization completed
# Detected 370 endings and 65 bifurcations

# %%
FP.skeletonize_with_kmm(visualize=False)

FP.detect_minutiae_with_directions()
# Out:
# Image saved to kmm_skeleton.bmp
# KMM skeletonization completed
# Detected 370 endings and 65 bifurcations with directions
