# %%
from fingerprint_processor import FingerprintProcessor

# %%
FP = FingerprintProcessor()

# %%
FP = FingerprintProcessor()
FP.load_image("../sample_data/sample_640×426.bmp")
FP.display_image()     

FP.normalize_fingerprint(100, 100)    
FP.display_image(FP.normalized_image, "Normalized Image")

FP.fingerprint_segmentation()       
FP.display_image(FP.segmented_image, "Segmented Image")

FP.create_directional_map()             

FP.frequency_map()
# Out:
# Loaded image ../sample_data/sample_640×426.bmp with shape (426, 640)
# Fingerprint normalized
# Fingerprint segmented
# Directional map created
# Frequency map created
# Median frequency: 0.1666666716337204

# %% [markdown]
# frequency map do poprawy chyba jeszcze
